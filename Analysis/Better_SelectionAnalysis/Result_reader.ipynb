# %%
# %cd /work/project/escience/ruttho/FCC-ee_SimpleDelphesAnalysis/Analysis/root_results/
# Out:
# /work/project/escience/ruttho/FCC-ee_SimpleDelphesAnalysis/Analysis/root_results

# %%
# %ls -lah
# Out:
# total 1.4G
# drwxrwxr-x  2 ruttho ruttho 4.0K Dec  2 14:35 ./
# drwxrwxr-x 10 ruttho ruttho 4.0K Dec  2 14:34 ../
# -rw-rw-r--  1 ruttho ruttho 1.4G Dec  2 14:58 output_file.root

# %%
# open root files and read histograms
import uproot
import numpy as np
import matplotlib.pyplot as plt
import mplhep as hep
import awkward as ak

# %%
# open root file as akward object
file = uproot.open("output_file.root")
# list all histograms in the root file
data_file = file['events;1']

# %%
data_file.arrays()
# Out:
# <Array [{HZ4Lep_MissingET_size: 1, ...}, ...] type='1000000 * {HZ4Lep_Missi...'>
